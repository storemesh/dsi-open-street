# %%
# !pip install git+https://github.com/storemesh/dsi-open-street.git
# !pip uninstall -y dsi-walking-map
# Out:
# ...
#   Cloning https://github.com/storemesh/dsi-open-street.git to /tmp/pip-req-build-io1oql36
#   Running command git clone --filter=blob:none --quiet https://github.com/storemesh/dsi-open-street.git /tmp/pip-req-build-io1oql36
#   Resolved https://github.com/storemesh/dsi-open-street.git to commit 347538424052c5bcd0b76717cd5b870759b65692
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for dsi-walking-map: filename=dsi_walking_map-0.1.0-py3-none-any.whl size=124406 sha256=9056bd238ac93bca2c64ab1bdbab711bd58638d031118c646708465f8092f0a9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hjihspwi/wheels/07/60/f6/222cfc37604479c5221d1f7020048f160b92dffca51a42a27d
# Successfully built dsi-walking-map
# ...

# %%
from dsi_walking_map import WalkerMap
import matplotlib.pyplot as plt

# %%
# กำหนดพิกัด ที่ต้องการ
lat, lon = 14.072134236615362, 100.60826137548777

# สร้าง Object เพียงครั้งเดียว input lat, lon
obj = WalkerMap(lat, lon)
# Out:
# Initializing WalkerMap... Fetching and processing data. 🏗️
# Data preparation complete. Ready to plot. ✨
# /usr/local/lib/python3.12/dist-packages/dsi_walking_map/plotter.py:52: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_services = gdf_services.set_geometry(gdf_services.geometry.centroid)

# %%
# 1. แสดงภาพถนน (Street)
print("Plotting Street layer...")
fig_street, ax_street = obj.street()
plt.show()
# Out:
# Plotting Street layer...

# %%
# 2. แสดงภาพสิ่งปลูกสร้าง (Building)
print("Plotting Building layer...")
fig_building, ax_building = obj.building()
plt.show()
# Out:
# Plotting Building layer...

# %%
# 3. แสดงภาพแหล่งน้ำ (Water)
print("Plotting Water layer...")
fig_water, ax_water = obj.water()
plt.show()
# Out:
# Plotting Water layer...

# %%
# --- เรียกใช้ method ใหม่ basemap() การรวมทุก layer : ถนน, น้ำ, สิ่งก่อสร้าง ---
print("Plotting the basemap without service pins...")
fig_base, ax_base = obj.basemap(area=False)
plt.show()
# Out:
# Plotting the basemap without service pins...

# %%
# --- เรียกใช้ method ใหม่ basemap() การรวมทุก layer : ถนน, น้ำ, สิ่งก่อสร้าง เพิ่ม area 15-minutes city ---
print("Plotting the basemap without service pins...")
fig_base, ax_base = obj.basemap(area=True)
plt.show()
# Out:
# Plotting the basemap without service pins...

# %%
# ผลลัพธ์สุดท้าย
print("Plotting combined output map...")
fig_main, ax_main = obj.output()
plt.show()
# Out:
# Plotting combined output map...
